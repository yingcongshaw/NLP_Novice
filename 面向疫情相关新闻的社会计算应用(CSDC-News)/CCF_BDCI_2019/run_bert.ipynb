# %%
import pandas as pd
import csv

# %% [markdown]
# ## 6.2.1、CCF_BDCI_2019互联网新闻情感分析模型训练

# %%
# !python run_bert.py \
--model_type 'bert' \
--model_name_or_path '../../../../Download/chinese-roberta-wwm-ext-large' \
--do_train  \
--do_eval \
--do_test \
--data_dir './data/' \
--output_dir './output/chinese-roberta-wwm-ext-large' \
--max_seq_length 256 \
--split_num 3 \
--lstm_hidden_size 512 \
--lstm_layers 1 \
--lstm_dropout 0.1 \
--eval_steps 200 \
--per_gpu_train_batch_size 4 \
--gradient_accumulation_steps 2 \
--warmup_steps 0 \
--per_gpu_eval_batch_size 8 \
--learning_rate 2e-5 \
--adam_epsilon 1e-6 \
--weight_decay 0 \
--train_steps 10000
# Out:
# 05/19/2023 19:10:13 - INFO - __main__ -     best_F1 = 0.7309855410612215
# 05/19/2023 19:10:13 - INFO - __main__ -     eval_F1 = 0.786446871636215
# 05/19/2023 19:10:13 - INFO - __main__ -     eval_loss = 0.4018295131733312
# 05/19/2023 19:10:13 - INFO - __main__ -     global_step = 400
# 05/19/2023 19:10:13 - INFO - __main__ -     loss = 0.5347
# ...
# Best F1 0.786446871636215
# Saving Model......
# ...
# loss 0.4979:  12%|██▊                    | 1199/10000 [42:47<1:11:48,  2.04it/s]05/19/2023 19:15:26 - INFO - __main__ -   ***** Report result *****
# 05/19/2023 19:15:26 - INFO - __main__ -     global_step = 600
# 05/19/2023 19:15:26 - INFO - __main__ -     train loss = 0.4979
# do eval now
# 05/19/2023 19:15:53 - INFO - __main__ -   ***** Running evaluation *****
# 05/19/2023 19:15:53 - INFO - __main__ -     Num examples = 7340
# 05/19/2023 19:15:53 - INFO - __main__ -     Batch size = 8
# 05/19/2023 19:31:36 - INFO - __main__ -     best_F1 = 0.786446871636215
# ...

# %% [markdown]
# ## 6.2.2、CSDC-News数据集新闻内容情感预测

# %% [markdown]
# #### 把news_keyword.ipybn中生成的的文件./news/output/news_emotion_test.csv，重命名为test.csv

# %%
# !mv ../news/output/news_emotion_test_100.csv ./data/test.csv

# %% [markdown]
# #### 调用上面训练好的模型，预测

# %%
# !python run_bert_test.py \
--model_type 'bert' \
--model_name_or_path '../../../../Download/chinese-roberta-wwm-ext-large' \
--do_test \
--data_dir './data/' \
--output_dir './output/chinese-roberta-wwm-ext-large' \
--max_seq_length 256 \
--split_num 3 \
--lstm_hidden_size 512 \
--lstm_layers 1 \
--lstm_dropout 0.1 \
--warmup_steps 0 \
--per_gpu_eval_batch_size 64 \
--learning_rate 2e-5 \
--adam_epsilon 1e-6 \
--weight_decay 0 \
--train_steps 10000
# Out:
# 05/21/2023 00:37:47 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 05/21/2023 00:37:47 - INFO - pytorch_transformers.tokenization_utils -   Model name '../../../../Download/chinese-roberta-wwm-ext-large' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc). Assuming '../../../../Download/chinese-roberta-wwm-ext-large' is a path or url to a directory containing tokenizer files.
# 05/21/2023 00:37:47 - INFO - pytorch_transformers.tokenization_utils -   loading file ../../../../Download/chinese-roberta-wwm-ext-large/vocab.txt
# ...

# %% [markdown]
# ## 6.2.3、CSDC-News数据集新闻评论情感预测

# %%
# !python run_bert_test.py \
--model_type 'bert' \
--model_name_or_path '../../../../Download/chinese-roberta-wwm-ext-large' \
--do_test \
--data_dir './data/' \
--output_dir './output/chinese-roberta-wwm-ext-large' \
--max_seq_length 256 \
--split_num 3 \
--lstm_hidden_size 512 \
--lstm_layers 1 \
--lstm_dropout 0.1 \
--warmup_steps 0 \
--per_gpu_eval_batch_size 64 \
--learning_rate 2e-5 \
--adam_epsilon 1e-6 \
--weight_decay 0 \
--train_steps 10000
# Out:
# 05/21/2023 06:29:40 - WARNING - __main__ -   Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# 05/21/2023 06:29:40 - INFO - pytorch_transformers.tokenization_utils -   Model name '../../../../Download/chinese-roberta-wwm-ext-large' not found in model shortcut name list (bert-base-uncased, bert-large-uncased, bert-base-cased, bert-large-cased, bert-base-multilingual-uncased, bert-base-multilingual-cased, bert-base-chinese, bert-base-german-cased, bert-large-uncased-whole-word-masking, bert-large-cased-whole-word-masking, bert-large-uncased-whole-word-masking-finetuned-squad, bert-large-cased-whole-word-masking-finetuned-squad, bert-base-cased-finetuned-mrpc). Assuming '../../../../Download/chinese-roberta-wwm-ext-large' is a path or url to a directory containing tokenizer files.
# 05/21/2023 06:29:40 - INFO - pytorch_transformers.tokenization_utils -   loading file ../../../../Download/chinese-roberta-wwm-ext-large/vocab.txt
# ...
